# %% [markdown]
# <p style="font-family: Arial; font-size:3.75em;color:purple; font-style:bold"><br>
# Twitter Sentiment Analysis<br></p>
#
# <p style="font-family: Arial; font-size:1.25em;color:#2462C0; font-style:bold"><br>Data Source: Twitter sentiment analysis Data Set from Analytics Vidhya</p>

# %%
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt

# %%
df = pd.read_csv("train.csv")
df.head(10)
# Out:
#    id  label                                              tweet
# 0   1      0   @user when a father is dysfunctional and is s...
# 1   2      0  @user @user thanks for #lyft credit i can't us...
# 2   3      0                                bihday your majesty
# 3   4      0  #model   i love u take with u all the time in ...
# 4   5      0             factsguide: society now    #motivation
# 5   6      0  [2/2] huge fan fare and big talking before the...
# 6   7      0   @user camping tomorrow @user @user @user @use...
# 7   8      0  the next school year is the year for exams.ð...
# 8   9      0  we won!!! love the land!!! #allin #cavs #champ...
# 9  10      0   @user @user welcome here !  i'm   it's so #gr...

# %%
tweets = df['tweet']
text = "".join(x for x in tweets)

# %% [markdown]
# Visualizing tweets using wordclouds

# %%
wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(text)

plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# As we can see, the redacted 'user' is the most common word. Let's filter it out and see how it changes the graphic.

# %%
stopwords = set(STOPWORDS)
stopwords.update(["user"])

wordcloud = WordCloud(max_font_size=50, max_words=100, stopwords=stopwords, background_color="white").generate(text)

plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# It seems like most tweets contain positive words! :)
